# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
from keras.layers import LeakyReLU

# %% [markdown]
# (a)  Download MNIST data using the built-in functionsin Keras

# %%
data = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# (b) Data Set is split into trainingData and testData, ValidationData can be splitted from trainingData while training the model.

# %%
trainingDataImages = data[0][0]
trainingDataLabels = data[0][1]
testDataImages = data[1][0]
testDataLabels = data[1][1]

# %%
class createModel:
  def __init__(self,num_hidden_layers,node_list,activation):
    
    self.num_hidden_layers = num_hidden_layers
    
    self.activation_function = activation
    
    self.node_list = node_list
    
    self.model = keras.Sequential()
    
    self.model.add(keras.layers.Flatten(input_shape=(28, 28)))
    
    for i in range(0,self.num_hidden_layers):
      
        self.model.add(keras.layers.Dense(self.node_list[i],activation=self.activation_function))
        
    self.model.add(keras.layers.Dense(10,activation="softmax"))
    
    self.weights = self.model.get_weights()
    
    
  def train_model(self,x_train,y_train,epochs,learning_rate):
    
    opt = keras.optimizers.SGD(learning_rate)
    
    self.model.compile(optimizer=opt,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
    
    #validation_split = 1/12 splits the trainingData(60000) into trainingData(55000) and validationData(5000)
    self.training_history = self.model.fit(x_train,y_train,epochs=epochs,shuffle=True,validation_split=1/12 )
    
    self.weights = self.model.get_weights()
    
    
  def test_model(self,x_test,y_test):
    (self.test_loss,self.test_accuracy)=self.model.evaluate(x_test,y_test)
    
    print("test_loss:",self.test_loss,"test_accuracy:",self.test_accuracy)

# %% [markdown]
# (c)
#
# i .
# Unnormalized model with one hidden layer(32 nodes) trained using stochastic gradient descent optimizer with learning rate 0.1

# %%
model1 = createModel(1,[32],"sigmoid")

model1.model.summary()
model1.train_model(trainingDataImages,trainingDataLabels,10,0.1)
print("\nTesting Model :")
model1.test_model(testDataImages,testDataLabels)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 6s 106us/sample - loss: 1.4706 - acc: 0.5111 - val_loss: 1.1471 - val_acc: 0.5826
# Epoch 2/10
# 55000/55000 [==============================] - 5s 85us/sample - loss: 1.0715 - acc: 0.6269 - val_loss: 0.9200 - val_acc: 0.6680
# Epoch 3/10
# 55000/55000 [==============================] - 4s 80us/sample - loss: 0.9783 - acc: 0.6626 - val_loss: 0.8879 - val_acc: 0.7012
# Epoch 4/10
# 55000/55000 [==============================] - 5s 84us/sample - loss: 0.9718 - acc: 0.6688 - val_loss: 0.9005 - val_acc: 0.6940
# Epoch 5/10
# 55000/55000 [==============================] - 5s 84us/sample - loss: 1.0000 - acc: 0.6596 - val_loss: 0.8416 - val_acc: 0.7412
# Epoch 6/10
# 55000/55000 [==============================] - 5s 82us/sample - loss: 1.0103 - acc: 0.6567 - val_loss: 0.9820 - val_acc: 0.6404
# Epoch 7/10
# 55000/55000 [==============================] - 5s 83us/sample - loss: 0.9194 - acc: 0.6897 - val_loss: 0.7253 - val_acc: 0.7514
# Epoch 8/10
# 55000/55000 [==============================] - 5s 82us/sample - loss: 0.9169 - acc: 0.6847 - val_loss: 0.9795 - val_acc: 0.6496
# Epoch 9/10
# 55000/55000 [==============================] - 5s 83us/sample - loss: 0.9712 - acc: 0.6716 - val_loss: 0.8134 - val_acc: 0.7344
# Epoch 10/10
# 55000/55000 [==============================] - 5s 82us/sample - loss: 0.9484 - acc: 0.6703 - val_loss: 0.8610 - val_acc: 0.7134
#
# Testing Model :
# 10000/10000 [==============================] - 1s 56us/sample - loss: 0.9166 - acc: 0.7044
# test_loss: 0.9166439739227294 test_accuracy: 0.7044

# %% [markdown]
# ii .
# Normalized model with one hidden layer(32 nodes) trained using stochastic gradient descent optimizer with learning rate 0.1

# %%
model2 = createModel(1,[32],"sigmoid")
trainingDataImagesNorm = trainingDataImages/255
testDataImagesNorm = testDataImages/255

model2.model.summary()
model2.train_model(trainingDataImagesNorm,trainingDataLabels,10,0.1)
print("\nTesting Model :")
model2.test_model(testDataImagesNorm,testDataLabels)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 5s 88us/sample - loss: 0.6371 - acc: 0.8445 - val_loss: 0.2755 - val_acc: 0.9298
# Epoch 2/10
# 55000/55000 [==============================] - 5s 85us/sample - loss: 0.3085 - acc: 0.9133 - val_loss: 0.2189 - val_acc: 0.9420
# Epoch 3/10
# 55000/55000 [==============================] - 5s 89us/sample - loss: 0.2585 - acc: 0.9264 - val_loss: 0.1945 - val_acc: 0.9482
# Epoch 4/10
# 55000/55000 [==============================] - 5s 88us/sample - loss: 0.2304 - acc: 0.9342 - val_loss: 0.1740 - val_acc: 0.9544
# Epoch 5/10
# 55000/55000 [==============================] - 5s 88us/sample - loss: 0.2101 - acc: 0.9398 - val_loss: 0.1636 - val_acc: 0.9562
# Epoch 6/10
# 55000/55000 [==============================] - 5s 88us/sample - loss: 0.1949 - acc: 0.9444 - val_loss: 0.1543 - val_acc: 0.9600
# Epoch 7/10
# 55000/55000 [==============================] - 5s 87us/sample - loss: 0.1824 - acc: 0.9474 - val_loss: 0.1486 - val_acc: 0.9608
# Epoch 8/10
# 55000/55000 [==============================] - 5s 85us/sample - loss: 0.1719 - acc: 0.9509 - val_loss: 0.1411 - val_acc: 0.9626
# Epoch 9/10
# 55000/55000 [==============================] - 5s 86us/sample - loss: 0.1628 - acc: 0.9524 - val_loss: 0.1394 - val_acc: 0.9622
# Epoch 10/10
# 55000/55000 [==============================] - 5s 86us/sample - loss: 0.1553 - acc: 0.9549 - val_loss: 0.1304 - val_acc: 0.9658
#
# Testing Model :
# 10000/10000 [==============================] - 1s 62us/sample - loss: 0.1586 - acc: 0.9529
# test_loss: 0.1586121327459812 test_accuracy: 0.9529

# %% [markdown]
# iii. The best performing model among i and ii is the the one in which data is normalized. Now we are going to train models model3a and model3b with 2 and 3 hidden layers respectively.

# %%
trainingDataImages = trainingDataImagesNorm
testDataImages = testDataImagesNorm

#model with 2 hidden layers
model3a = createModel(2,[64,64],"sigmoid")

model3a.model.summary()
model3a.train_model(trainingDataImages,trainingDataLabels,10,0.1)
print("\nTesting Model :")
model3a.test_model(testDataImages,testDataLabels)
print()

#model with 3 hidden layers
model3b = createModel(3,[64,64,64],"sigmoid")

model3b.model.summary()
model3b.train_model(trainingDataImages,trainingDataLabels,10,0.1)
print("\nTesting Model :")
model3b.test_model(testDataImages,testDataLabels)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.9884 - acc: 0.7134 - val_loss: 0.3479 - val_acc: 0.9090
# Epoch 2/10
# 55000/55000 [==============================] - 5s 90us/sample - loss: 0.3525 - acc: 0.9007 - val_loss: 0.2419 - val_acc: 0.9316
# Epoch 3/10
# 55000/55000 [==============================] - 5s 90us/sample - loss: 0.2814 - acc: 0.9183 - val_loss: 0.2060 - val_acc: 0.9416
# Epoch 4/10
# 55000/55000 [==============================] - 5s 91us/sample - loss: 0.2395 - acc: 0.9299 - val_loss: 0.1766 - val_acc: 0.9532
# Epoch 5/10
# 55000/55000 [==============================] - 5s 91us/sample - loss: 0.2092 - acc: 0.9387 - val_loss: 0.1579 - val_acc: 0.9592
# Epoch 6/10
# 55000/55000 [==============================] - 5s 91us/sample - loss: 0.1853 - acc: 0.9462 - val_loss: 0.1419 - val_acc: 0.9636
# Epoch 7/10
# 55000/55000 [==============================] - 5s 91us/sample - loss: 0.1660 - acc: 0.9511 - val_loss: 0.1330 - val_acc: 0.9664
# Epoch 8/10
# 55000/55000 [==============================] - 5s 91us/sample - loss: 0.1494 - acc: 0.9565 - val_loss: 0.1236 - val_acc: 0.9670
# Epoch 9/10
# 55000/55000 [==============================] - 5s 91us/sample - loss: 0.1361 - acc: 0.9606 - val_loss: 0.1141 - val_acc: 0.9712
# Epoch 10/10
# 55000/55000 [==============================] - 5s 91us/sample - loss: 0.1248 - acc: 0.9636 - val_loss: 0.1091 - val_acc: 0.9696
#
# Testing Model :
# 10000/10000 [==============================] - 1s 63us/sample - loss: 0.1274 - acc: 0.9616
# test_loss: 0.12738648625165225 test_accuracy: 0.9616
#
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                650
# =================================================================
# Total params: 59,210
# Trainable params: 59,210
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 6s 101us/sample - loss: 1.8839 - acc: 0.3373 - val_loss: 0.8480 - val_acc: 0.7658
# Epoch 2/10
# 55000/55000 [==============================] - 5s 99us/sample - loss: 0.5882 - acc: 0.8317 - val_loss: 0.3436 - val_acc: 0.9070
# Epoch 3/10
# 55000/55000 [==============================] - 5s 99us/sample - loss: 0.3714 - acc: 0.8933 - val_loss: 0.2568 - val_acc: 0.9296
# Epoch 4/10
# 55000/55000 [==============================] - 5s 99us/sample - loss: 0.2848 - acc: 0.9182 - val_loss: 0.2236 - val_acc: 0.9354
# Epoch 5/10
# 55000/55000 [==============================] - 5s 99us/sample - loss: 0.2305 - acc: 0.9333 - val_loss: 0.1668 - val_acc: 0.9522
# Epoch 6/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 0.1928 - acc: 0.9438 - val_loss: 0.1502 - val_acc: 0.9552
# Epoch 7/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 0.1662 - acc: 0.9504 - val_loss: 0.1365 - val_acc: 0.9620
# Epoch 8/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 0.1461 - acc: 0.9569 - val_loss: 0.1319 - val_acc: 0.9632
# Epoch 9/10
# 55000/55000 [==============================] - 5s 97us/sample - loss: 0.1307 - acc: 0.9616 - val_loss: 0.1175 - val_acc: 0.9642
# Epoch 10/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 0.1185 - acc: 0.9655 - val_loss: 0.1105 - val_acc: 0.9688
#
# Testing Model :
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.1251 - acc: 0.9623
# test_loss: 0.12514717495441438 test_accuracy: 0.9623

# %% [markdown]
# iv.  The model which is having 2 hidden layers is the best performing model in iii. Now we are going to train this model with learning rate of 0.001 and 0.0001.

# %%
#model with learning rate 0.001
model4a = createModel(2,[64,64],"sigmoid")

model4a.model.summary()
model4a.train_model(trainingDataImages,trainingDataLabels,10,0.001)
print("\nTesting Model :")
model4a.test_model(testDataImages,testDataLabels)
print()

#model with learning rate 0.0001
model4b = createModel(2,[64,64],"sigmoid")

model4b.model.summary()
model4b.train_model(trainingDataImages,trainingDataLabels,10,0.0001)
print("\nTesting Model :")
model4b.test_model(testDataImages,testDataLabels)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 2.3209 - acc: 0.1095 - val_loss: 2.2942 - val_acc: 0.1082
# Epoch 2/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 2.2886 - acc: 0.1147 - val_loss: 2.2803 - val_acc: 0.1170
# Epoch 3/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 2.2749 - acc: 0.1500 - val_loss: 2.2653 - val_acc: 0.1956
# Epoch 4/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 2.2607 - acc: 0.2193 - val_loss: 2.2498 - val_acc: 0.2662
# Epoch 5/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 2.2454 - acc: 0.2857 - val_loss: 2.2334 - val_acc: 0.3408
# Epoch 6/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 2.2289 - acc: 0.3497 - val_loss: 2.2155 - val_acc: 0.3860
# Epoch 7/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 2.2105 - acc: 0.4006 - val_loss: 2.1954 - val_acc: 0.4126
# Epoch 8/10
# 55000/55000 [==============================] - 5s 92us/sample - loss: 2.1901 - acc: 0.4291 - val_loss: 2.1727 - val_acc: 0.4808
# Epoch 9/10
# 55000/55000 [==============================] - 5s 92us/sample - loss: 2.1670 - acc: 0.4705 - val_loss: 2.1469 - val_acc: 0.5280
# Epoch 10/10
# 55000/55000 [==============================] - 5s 92us/sample - loss: 2.1408 - acc: 0.5009 - val_loss: 2.1178 - val_acc: 0.5516
#
# Testing Model :
# 10000/10000 [==============================] - 1s 64us/sample - loss: 2.1220 - acc: 0.5315
# test_loss: 2.122042381286621 test_accuracy: 0.5315
#
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_5 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 5s 96us/sample - loss: 2.4435 - acc: 0.1022 - val_loss: 2.4084 - val_acc: 0.1018
# Epoch 2/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 2.3793 - acc: 0.1022 - val_loss: 2.3620 - val_acc: 0.1018
# Epoch 3/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 2.3446 - acc: 0.1022 - val_loss: 2.3350 - val_acc: 0.1018
# Epoch 4/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 2.3242 - acc: 0.1022 - val_loss: 2.3188 - val_acc: 0.1014
# Epoch 5/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 2.3119 - acc: 0.1052 - val_loss: 2.3088 - val_acc: 0.1258
# Epoch 6/10
# 55000/55000 [==============================] - 5s 96us/sample - loss: 2.3044 - acc: 0.1340 - val_loss: 2.3026 - val_acc: 0.1432
# Epoch 7/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 2.2996 - acc: 0.1426 - val_loss: 2.2985 - val_acc: 0.1286
# Epoch 8/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 2.2965 - acc: 0.1292 - val_loss: 2.2956 - val_acc: 0.1166
# Epoch 9/10
# 55000/55000 [==============================] - 5s 96us/sample - loss: 2.2942 - acc: 0.1228 - val_loss: 2.2935 - val_acc: 0.1106
# Epoch 10/10
# 55000/55000 [==============================] - 6s 101us/sample - loss: 2.2924 - acc: 0.1173 - val_loss: 2.2917 - val_acc: 0.1088
#
# Testing Model :
# 10000/10000 [==============================] - 1s 72us/sample - loss: 2.2918 - acc: 0.1171
# test_loss: 2.2917566093444823 test_accuracy: 0.1171

# %% [markdown]
# Obsservations: The accuracy is very low because of the low learning rate.

# %% [markdown]
# v . The best performing model for iv. is with the learning rate 0.001. Training the model with the number of nodes in hidden layers with 128 and 64.

# %%
#model with nodes 128 and 64
model5a = createModel(2,[128,64],"sigmoid")

model5a.model.summary()
model5a.train_model(trainingDataImages,trainingDataLabels,10,0.001)
print("\nTesting Model :")
model5a.test_model(testDataImages,testDataLabels)
print()

#model with nodes 64 and 128
model5b = createModel(2,[64,128],"sigmoid")

model5b.model.summary()
model5b.train_model(trainingDataImages,trainingDataLabels,10,0.001)
print("\nTesting Model :")
model5b.test_model(testDataImages,testDataLabels)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 6s 103us/sample - loss: 2.3077 - acc: 0.1159 - val_loss: 2.2807 - val_acc: 0.1116
# Epoch 2/10
# 55000/55000 [==============================] - 5s 99us/sample - loss: 2.2719 - acc: 0.1712 - val_loss: 2.2616 - val_acc: 0.1994
# Epoch 3/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 2.2531 - acc: 0.2487 - val_loss: 2.2411 - val_acc: 0.3054
# Epoch 4/10
# 55000/55000 [==============================] - 5s 96us/sample - loss: 2.2329 - acc: 0.3306 - val_loss: 2.2193 - val_acc: 0.3248
# Epoch 5/10
# 55000/55000 [==============================] - 5s 97us/sample - loss: 2.2109 - acc: 0.3758 - val_loss: 2.1945 - val_acc: 0.4326
# Epoch 6/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 2.1864 - acc: 0.4377 - val_loss: 2.1673 - val_acc: 0.4456
# Epoch 7/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 2.1586 - acc: 0.4653 - val_loss: 2.1370 - val_acc: 0.5030
# Epoch 8/10
# 55000/55000 [==============================] - 5s 97us/sample - loss: 2.1272 - acc: 0.5002 - val_loss: 2.1014 - val_acc: 0.5468
# Epoch 9/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 2.0912 - acc: 0.5290 - val_loss: 2.0612 - val_acc: 0.5770
# Epoch 10/10
# 55000/55000 [==============================] - 5s 97us/sample - loss: 2.0501 - acc: 0.5527 - val_loss: 2.0156 - val_acc: 0.5890
#
# Testing Model :
# 10000/10000 [==============================] - 1s 67us/sample - loss: 2.0219 - acc: 0.5637
# test_loss: 2.0218931818008423 test_accuracy: 0.5637
#
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_22 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 59,850
# Trainable params: 59,850
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 6s 101us/sample - loss: 2.3118 - acc: 0.1134 - val_loss: 2.2916 - val_acc: 0.1062
# Epoch 2/10
# 55000/55000 [==============================] - 5s 96us/sample - loss: 2.2859 - acc: 0.1203 - val_loss: 2.2802 - val_acc: 0.1090
# Epoch 3/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 2.2748 - acc: 0.1380 - val_loss: 2.2681 - val_acc: 0.1450
# Epoch 4/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 2.2630 - acc: 0.1911 - val_loss: 2.2550 - val_acc: 0.2012
# Epoch 5/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 2.2501 - acc: 0.2449 - val_loss: 2.2409 - val_acc: 0.3016
# Epoch 6/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 2.2358 - acc: 0.3122 - val_loss: 2.2253 - val_acc: 0.3172
# Epoch 7/10
# 55000/55000 [==============================] - 5s 92us/sample - loss: 2.2197 - acc: 0.3577 - val_loss: 2.2070 - val_acc: 0.3928
# Epoch 8/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 2.2012 - acc: 0.4119 - val_loss: 2.1866 - val_acc: 0.4656
# Epoch 9/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 2.1801 - acc: 0.4557 - val_loss: 2.1632 - val_acc: 0.4636
# Epoch 10/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 2.1556 - acc: 0.4835 - val_loss: 2.1352 - val_acc: 0.4864
#
# Testing Model :
# 10000/10000 [==============================] - 1s 70us/sample - loss: 2.1380 - acc: 0.4724
# test_loss: 2.1380331695556642 test_accuracy: 0.4724

# %% [markdown]
# vi. The best performing model in v is the hidden layers with nodes 128 and 64. Training models with tanh, relu and leaky relu

# %%
#model with tanh
model6a = createModel(2,[128,64],"tanh")

model6a.model.summary()
model6a.train_model(trainingDataImages,trainingDataLabels,10,0.001)
print("\nTesting Model :")
model6a.test_model(testDataImages,testDataLabels)
print()

#model with relu
model6b = createModel(2,[128,64],"relu")

model6b.model.summary()
model6b.train_model(trainingDataImages,trainingDataLabels,10,0.001)
print("\nTesting Model :")
model6b.test_model(testDataImages,testDataLabels)
print()

#model with leaky relu
model6c = createModel(2,[128,64],LeakyReLU(alpha=0.1))

model6c.model.summary()
model6c.train_model(trainingDataImages,trainingDataLabels,10,0.001)
print("\nTesting Model :")
model6c.test_model(testDataImages,testDataLabels)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_24 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 6s 101us/sample - loss: 1.4970 - acc: 0.6062 - val_loss: 0.9521 - val_acc: 0.8208
# Epoch 2/10
# 55000/55000 [==============================] - 5s 97us/sample - loss: 0.8478 - acc: 0.8099 - val_loss: 0.6379 - val_acc: 0.8742
# Epoch 3/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.6528 - acc: 0.8449 - val_loss: 0.5078 - val_acc: 0.8942
# Epoch 4/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.5576 - acc: 0.8621 - val_loss: 0.4372 - val_acc: 0.9018
# Epoch 5/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.5002 - acc: 0.8717 - val_loss: 0.3930 - val_acc: 0.9082
# Epoch 6/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.4614 - acc: 0.8791 - val_loss: 0.3623 - val_acc: 0.9128
# Epoch 7/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.4330 - acc: 0.8844 - val_loss: 0.3400 - val_acc: 0.9162
# Epoch 8/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.4111 - acc: 0.8890 - val_loss: 0.3224 - val_acc: 0.9186
# Epoch 9/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.3937 - acc: 0.8918 - val_loss: 0.3082 - val_acc: 0.9212
# Epoch 10/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.3792 - acc: 0.8948 - val_loss: 0.2971 - val_acc: 0.9236
#
# Testing Model :
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.3499 - acc: 0.9064
# test_loss: 0.34992577372789385 test_accuracy: 0.9064
#
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_9 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_27 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 1.8920 - acc: 0.4850 - val_loss: 1.3841 - val_acc: 0.7348
# Epoch 2/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 1.0656 - acc: 0.7717 - val_loss: 0.7393 - val_acc: 0.8538
# Epoch 3/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.6934 - acc: 0.8358 - val_loss: 0.5197 - val_acc: 0.8866
# Epoch 4/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.5503 - acc: 0.8602 - val_loss: 0.4229 - val_acc: 0.9008
# Epoch 5/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.4770 - acc: 0.8739 - val_loss: 0.3691 - val_acc: 0.9092
# Epoch 6/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.4318 - acc: 0.8830 - val_loss: 0.3358 - val_acc: 0.9122
# Epoch 7/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.4006 - acc: 0.8901 - val_loss: 0.3109 - val_acc: 0.9158
# Epoch 8/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.3778 - acc: 0.8945 - val_loss: 0.2939 - val_acc: 0.9194
# Epoch 9/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.3598 - acc: 0.8992 - val_loss: 0.2797 - val_acc: 0.9232
# Epoch 10/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.3451 - acc: 0.9027 - val_loss: 0.2680 - val_acc: 0.9254
#
# Testing Model :
# 10000/10000 [==============================] - 1s 67us/sample - loss: 0.3225 - acc: 0.9100
# test_loss: 0.32251799122691155 test_accuracy: 0.91
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_10 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_30 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_31 (Dense)             (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 5s 96us/sample - loss: 1.8766 - acc: 0.4871 - val_loss: 1.3504 - val_acc: 0.7542
# Epoch 2/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 1.0545 - acc: 0.7821 - val_loss: 0.7247 - val_acc: 0.8586
# Epoch 3/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.6878 - acc: 0.8362 - val_loss: 0.5101 - val_acc: 0.8882
# Epoch 4/10
# 55000/55000 [==============================] - 5s 91us/sample - loss: 0.5470 - acc: 0.8602 - val_loss: 0.4150 - val_acc: 0.9020
# Epoch 5/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.4753 - acc: 0.8741 - val_loss: 0.3637 - val_acc: 0.9092
# Epoch 6/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.4318 - acc: 0.8832 - val_loss: 0.3310 - val_acc: 0.9152
# Epoch 7/10
# 55000/55000 [==============================] - 5s 92us/sample - loss: 0.4023 - acc: 0.8893 - val_loss: 0.3082 - val_acc: 0.9212
# Epoch 8/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.3806 - acc: 0.8938 - val_loss: 0.2919 - val_acc: 0.9258
# Epoch 9/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.3637 - acc: 0.8979 - val_loss: 0.2792 - val_acc: 0.9270
# Epoch 10/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.3499 - acc: 0.9015 - val_loss: 0.2688 - val_acc: 0.9282
#
# Testing Model :
# 10000/10000 [==============================] - 1s 64us/sample - loss: 0.3232 - acc: 0.9108
# test_loss: 0.3232159404814243 test_accuracy: 0.9108

# %% [markdown]
# vii. Among all the hyperparameters lr = 0.1 is best performing.

# %%
model7 = createModel(2,[128,64],LeakyReLU(alpha=0.1))

model7.model.summary()
model7.train_model(trainingDataImages,trainingDataLabels,10,0.01)
print("\nTesting Model :")
model7.test_model(testDataImages,testDataLabels)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_11 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_34 (Dense)             (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 5s 97us/sample - loss: 0.6506 - acc: 0.8277 - val_loss: 0.2718 - val_acc: 0.9214
# Epoch 2/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.3109 - acc: 0.9121 - val_loss: 0.2224 - val_acc: 0.9348
# Epoch 3/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.2604 - acc: 0.9268 - val_loss: 0.1952 - val_acc: 0.9442
# Epoch 4/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.2282 - acc: 0.9354 - val_loss: 0.1692 - val_acc: 0.9538
# Epoch 5/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.2030 - acc: 0.9417 - val_loss: 0.1562 - val_acc: 0.9586
# Epoch 6/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.1821 - acc: 0.9476 - val_loss: 0.1405 - val_acc: 0.9638
# Epoch 7/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 0.1651 - acc: 0.9530 - val_loss: 0.1371 - val_acc: 0.9630
# Epoch 8/10
# 55000/55000 [==============================] - 5s 97us/sample - loss: 0.1509 - acc: 0.9567 - val_loss: 0.1246 - val_acc: 0.9668
# Epoch 9/10
# 55000/55000 [==============================] - 5s 99us/sample - loss: 0.1387 - acc: 0.9602 - val_loss: 0.1173 - val_acc: 0.9680
# Epoch 10/10
# 55000/55000 [==============================] - 5s 98us/sample - loss: 0.1280 - acc: 0.9635 - val_loss: 0.1128 - val_acc: 0.9698
#
# Testing Model :
# 10000/10000 [==============================] - 1s 65us/sample - loss: 0.1319 - acc: 0.9604
# test_loss: 0.13192787636220454 test_accuracy: 0.9604

# %% [markdown]
# viii. Among all the models trained above the model with learning rate 0.1 , 2 hidden layers with 128 and 64 nodes , leaky relu activation function for the hidden layers. I will choose the best model based on the least loss and higher accuracy.

# %%
model8 = createModel(2,[128,64],LeakyReLU(alpha=0.1))

model8.model.summary()
model8.train_model(trainingDataImages,trainingDataLabels,10,0.01)
print("\nTesting Model :")
model8.test_model(testDataImages,testDataLabels)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_12 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_36 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                650
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/10
# 55000/55000 [==============================] - 5s 99us/sample - loss: 0.6980 - acc: 0.8108 - val_loss: 0.2765 - val_acc: 0.9274
# Epoch 2/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.3173 - acc: 0.9095 - val_loss: 0.2187 - val_acc: 0.9408
# Epoch 3/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.2645 - acc: 0.9245 - val_loss: 0.1949 - val_acc: 0.9470
# Epoch 4/10
# 55000/55000 [==============================] - 5s 95us/sample - loss: 0.2309 - acc: 0.9338 - val_loss: 0.1729 - val_acc: 0.9516
# Epoch 5/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.2056 - acc: 0.9411 - val_loss: 0.1586 - val_acc: 0.9552
# Epoch 6/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.1852 - acc: 0.9466 - val_loss: 0.1434 - val_acc: 0.9602
# Epoch 7/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.1689 - acc: 0.9517 - val_loss: 0.1329 - val_acc: 0.9646
# Epoch 8/10
# 55000/55000 [==============================] - 5s 94us/sample - loss: 0.1549 - acc: 0.9553 - val_loss: 0.1243 - val_acc: 0.9670
# Epoch 9/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.1423 - acc: 0.9593 - val_loss: 0.1209 - val_acc: 0.9650
# Epoch 10/10
# 55000/55000 [==============================] - 5s 93us/sample - loss: 0.1326 - acc: 0.9623 - val_loss: 0.1132 - val_acc: 0.9664
#
# Testing Model :
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.1384 - acc: 0.9591
# test_loss: 0.1384312619239092 test_accuracy: 0.9591
